# %%
import requests
from bs4 import BeautifulSoup
import time
import numpy as np
import pandas as pd

# %%
# first pull the HTML from the page that links to all of the pages with the links.
# in this case, this page gives the links list pages of sci-fi films by decade.
# just go to https://en.wikipedia.org/wiki/Lists_of_science_fiction_films
# to see what I'm pulling from.
html = requests.get('https://en.wikipedia.org/wiki/Lists_of_science_fiction_films')

#turn the HTML into a beautiful soup text object
b = BeautifulSoup(html.text, 'lxml')

# %%
# create an mpty list where those links will go.
links = []

# in this case, all of the links we're in a '<li>' brackets.
for i in b.find_all(name = 'li'):
    # pull the actual link for each one
    for link in i.find_all('a', href=True):
        links.append(link['href'])
# the above code ends up pulling more links than I want,
# so I just use the ones I want
links = links[1:11]
# each link only returns something like 'wiki/List_of_science_fiction_films_of_the_1920s'
# so I add the other part of the URL to each.
decade_links = ['https://en.wikipedia.org' + i for i in links]

# %%
decade_links
# Out:
# ['https://en.wikipedia.org/wiki/List_of_science_fiction_films_before_1920',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_1920s',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_1930s',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_1940s',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_1950s',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_1960s',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_1970s',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_1980s',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_1990s',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_2000s',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_2010s',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_2020s',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_television_films',
#  'https://en.wikipedia.org/wiki/Template:Scififilmlist',
#  'https://en.wikipedia.org/wiki/Template_talk:Scififilmlist',
#  'https://en.wikipedia.orghttps://en.wikipedia.org/w/index.php?title=Template:Scififilmlist&action=edit',
#  'https://en.wikipedia.org#Lists_by_decade',
#  'https://en.wikipedia.org#See_also',
#  'https://en.wikipedia.org#References',
#  'https://en.wikipedia.org#External_links',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_films_before_1920',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_1920s',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_1930s',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_1940s',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_1950s',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_1960s',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_1970s',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_1980s',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_1990s',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_2000s',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_2010s',
#  'https://en.wikipedia.org/wiki/List_of_comic_science_fiction_films',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_horror_films',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_thriller_films',
#  'https://en.wikipedia.org/wiki/List_of_films_featuring_extraterrestrials',
#  'https://en.wikipedia.org/wiki/List_of_films_set_in_the_future',
#  'https://en.wikipedia.org/wiki/List_of_time_travel_science_fiction#Time_travel_in_science_fiction_films',
#  'https://en.wikipedia.org/wiki/List_of_films_featuring_space_stations',
#  'https://en.wikipedia.org/wiki/Fantasy_film',
#  'https://en.wikipedia.org/wiki/Horror_film',
#  'https://en.wikipedia.org/wiki/Superhero_film',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_television_films',
#  'https://en.wikipedia.org/wiki/List_of_Sci_Fi_Pictures_original_films',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_anime',
#  'https://en.wikipedia.org/wiki/List_of_film_serials',
#  'https://en.wikipedia.org/wiki/List_of_fantasy_films',
#  'https://en.wikipedia.org/wiki/Lists_of_horror_films',
#  'https://en.wikipedia.org/wiki/List_of_stories_set_in_a_future_now_past',
#  'https://en.wikipedia.org/wiki/List_of_fictional_spacecraft',
#  'https://en.wikipedia.org/wiki/List_of_fictional_space_stations',
#  'https://en.wikipedia.org/wiki/Starship_(interstellar_spacecraft)#Fictional_examples',
#  'https://en.wikipedia.org/wiki/Hugo_Award_for_Best_Dramatic_Presentation',
#  'https://en.wikipedia.org/wiki/Hugo_Award_for_Best_Dramatic_Presentation,_Long_Form',
#  'https://en.wikipedia.org/wiki/Saturn_Award_for_Best_Science_Fiction_Film',
#  'https://en.wikipedia.org/wiki/Films_considered_the_greatest_ever',
#  'https://en.wikipedia.org/wiki/List_of_films_considered_the_worst',
#  'https://en.wikipedia.org/wiki/Bill_Warren_(film_historian_and_critic)',
#  'https://en.wikipedia.org/wiki/International_Standard_Book_Number',
#  'https://en.wikipedia.org/wiki/Special:BookSources/0-7864-0479-5',
#  'https://en.wikipedia.org/wiki/International_Standard_Book_Number',
#  'https://en.wikipedia.org/wiki/Special:BookSources/1-57061-415-6',
#  'https://en.wikipedia.org/wiki/International_Standard_Book_Number',
#  'https://en.wikipedia.org/wiki/Special:BookSources/0-7876-0615-4',
#  'https://en.wikipedia.orghttp://www.filmsandtv.com/genre.php?gs=2000Sci-Fi',
#  'https://en.wikipedia.orghttp://sepnet.com/rcramer/scifi.htm',
#  'https://en.wikipedia.orghttp://top-best-movies.com/',
#  'https://en.wikipedia.org/wiki/Template:Films_by_genre',
#  'https://en.wikipedia.org/wiki/Template_talk:Films_by_genre',
#  'https://en.wikipedia.orghttps://en.wikipedia.org/w/index.php?title=Template:Films_by_genre&action=edit',
#  'https://en.wikipedia.org/wiki/Lists_of_action_films',
#  'https://en.wikipedia.org/wiki/List_of_martial_arts_films',
#  'https://en.wikipedia.org/wiki/List_of_martial_arts_films',
#  'https://en.wikipedia.org/wiki/Lists_of_adventure_films',
#  'https://en.wikipedia.org/wiki/List_of_pirate_films',
#  'https://en.wikipedia.org/wiki/List_of_pirate_films',
#  'https://en.wikipedia.org/wiki/Lists_of_animated_feature_films',
#  'https://en.wikipedia.org/wiki/Lists_of_avant-garde_films',
#  'https://en.wikipedia.org/wiki/List_of_biographical_films',
#  'https://en.wikipedia.org/wiki/List_of_blaxploitation_films',
#  'https://en.wikipedia.org/wiki/List_of_children%27s_films',
#  'https://en.wikipedia.org/wiki/List_of_Christian_films',
#  'https://en.wikipedia.org/wiki/Lists_of_comedy_films',
#  'https://en.wikipedia.org/wiki/Lists_of_crime_films',
#  'https://en.wikipedia.org/wiki/List_of_disaster_films',
#  'https://en.wikipedia.org/wiki/List_of_documentary_films',
#  'https://en.wikipedia.org/wiki/List_of_drama_films',
#  'https://en.wikipedia.org/wiki/List_of_historical_period_drama_films_and_series_set_in_Near_Eastern_and_Western_civilization',
#  'https://en.wikipedia.org/wiki/List_of_historical_period_drama_films_and_series_set_in_Near_Eastern_and_Western_civilization',
#  'https://en.wikipedia.org/wiki/List_of_economics_films',
#  'https://en.wikipedia.org/wiki/Lists_of_erotic_films',
#  'https://en.wikipedia.org/wiki/Lists_of_fantasy_films',
#  'https://en.wikipedia.org/wiki/List_of_ghost_films',
#  'https://en.wikipedia.org/wiki/Lists_of_horror_films',
#  'https://en.wikipedia.org/wiki/List_of_eco-horror_films',
#  'https://en.wikipedia.org/wiki/List_of_disaster_films',
#  'https://en.wikipedia.org/wiki/Kaiju',
#  'https://en.wikipedia.org/wiki/List_of_films_featuring_giant_monsters',
#  'https://en.wikipedia.org/wiki/List_of_natural_horror_films',
#  'https://en.wikipedia.org/wiki/Psychological_horror',
#  'https://en.wikipedia.org/wiki/List_of_eco-horror_films',
#  'https://en.wikipedia.org/wiki/List_of_disaster_films',
#  'https://en.wikipedia.org/wiki/Kaiju',
#  'https://en.wikipedia.org/wiki/List_of_films_featuring_giant_monsters',
#  'https://en.wikipedia.org/wiki/List_of_natural_horror_films',
#  'https://en.wikipedia.org/wiki/Psychological_horror',
#  'https://en.wikipedia.org/wiki/List_of_independent_short_films',
#  'https://en.wikipedia.org/wiki/List_of_LGBT-related_films',
#  'https://en.wikipedia.org/wiki/List_of_mockumentaries',
#  'https://en.wikipedia.org/wiki/List_of_monster_movies',
#  'https://en.wikipedia.org/wiki/Evil_clown',
#  'https://en.wikipedia.org/wiki/Killer_toy',
#  'https://en.wikipedia.org/wiki/Evil_clown',
#  'https://en.wikipedia.org/wiki/Killer_toy',
#  'https://en.wikipedia.org/wiki/List_of_musical_films_by_year',
#  'https://en.wikipedia.org/wiki/List_of_mystery_films',
#  'https://en.wikipedia.org/wiki/List_of_film_noir_titles',
#  'https://en.wikipedia.org/wiki/List_of_neo-noir_titles',
#  'https://en.wikipedia.org/wiki/List_of_religious_films',
#  'https://en.wikipedia.org/wiki/List_of_romance_films',
#  'https://en.wikipedia.org/wiki/List_of_romantic_comedy_films',
#  'https://en.wikipedia.org/wiki/List_of_sports_films',
#  'https://en.wikipedia.org/wiki/List_of_films_featuring_slavery',
#  'https://en.wikipedia.org/wiki/List_of_American_superhero_films',
#  'https://en.wikipedia.org/wiki/List_of_teen_films',
#  'https://en.wikipedia.org/wiki/Lists_of_thriller_films',
#  'https://en.wikipedia.org/wiki/Legal_thriller',
#  'https://en.wikipedia.org/wiki/Legal_thriller',
#  'https://en.wikipedia.org/wiki/List_of_war_films_and_TV_specials',
#  'https://en.wikipedia.org/wiki/List_of_anti-war_films',
#  'https://en.wikipedia.org/wiki/List_of_anti-war_films',
#  'https://en.wikipedia.org/wiki/Lists_of_Western_films',
#  'https://en.wikipedia.org/wiki/List_of_Spaghetti_Western_films',
#  'https://en.wikipedia.org/wiki/List_of_Spaghetti_Western_films',
#  'https://en.wikipedia.org/wiki/Template:Science_fiction',
#  'https://en.wikipedia.org/wiki/Template_talk:Science_fiction',
#  'https://en.wikipedia.orghttps://en.wikipedia.org/w/index.php?title=Template:Science_fiction&action=edit',
#  'https://en.wikipedia.org/wiki/List_of_science-fiction_authors',
#  'https://en.wikipedia.org/wiki/Definitions_of_science_fiction',
#  'https://en.wikipedia.org/wiki/Hard_science_fiction',
#  'https://en.wikipedia.org/wiki/Soft_science_fiction',
#  'https://en.wikipedia.org/wiki/Hard_science_fiction',
#  'https://en.wikipedia.org/wiki/Soft_science_fiction',
#  'https://en.wikipedia.org/wiki/History_of_science_fiction',
#  'https://en.wikipedia.org/wiki/Timeline_of_science_fiction',
#  'https://en.wikipedia.org/wiki/Golden_Age_of_Science_Fiction',
#  'https://en.wikipedia.org/wiki/New_Wave_science_fiction',
#  'https://en.wikipedia.org/wiki/Anthropological_science_fiction',
#  'https://en.wikipedia.org/wiki/Biopunk',
#  'https://en.wikipedia.org/wiki/Cyberpunk',
#  'https://en.wikipedia.org/wiki/Dieselpunk',
#  'https://en.wikipedia.org/wiki/Steampunk',
#  'https://en.wikipedia.org/wiki/Apocalyptic_and_post-apocalyptic_fiction',
#  'https://en.wikipedia.org/wiki/Christian_science_fiction',
#  'https://en.wikipedia.org/wiki/Climate_fiction',
#  'https://en.wikipedia.org/wiki/Comic_science_fiction',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_sitcoms',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_sitcoms',
#  'https://en.wikipedia.org/wiki/Dying_Earth_genre',
#  'https://en.wikipedia.org/wiki/Feminist_science_fiction',
#  'https://en.wikipedia.org/wiki/Gothic_science_fiction',
#  'https://en.wikipedia.org/wiki/Libertarian_science_fiction',
#  'https://en.wikipedia.org/wiki/Military_science_fiction',
#  'https://en.wikipedia.org/wiki/Mundane_science_fiction',
#  'https://en.wikipedia.org/wiki/Parallel_universes_in_fiction#Science_fiction',
#  'https://en.wikipedia.org/wiki/Planetary_romance',
#  'https://en.wikipedia.org/wiki/Scientific_romance',
#  'https://en.wikipedia.org/wiki/Social_science_fiction',
#  'https://en.wikipedia.org/wiki/Space_opera',
#  'https://en.wikipedia.org/wiki/Space_Western',
#  'https://en.wikipedia.org/wiki/Sword_and_planet',
#  'https://en.wikipedia.org/wiki/Science_fiction_convention',
#  'https://en.wikipedia.org/wiki/Science_fiction_fandom',
#  'https://en.wikipedia.org/wiki/Science-fiction_fanzine',
#  'https://en.wikipedia.org/wiki/Internet_Speculative_Fiction_Database',
#  'https://en.wikipedia.org/wiki/Science_fiction_libraries_and_museums',
#  'https://en.wikipedia.org/wiki/EMP_Museum#Science_Fiction_Museum',
#  'https://en.wikipedia.org/wiki/Science_fiction_studies',
#  'https://en.wikipedia.org/wiki/Women_in_speculative_fiction',
#  'https://en.wikipedia.org/wiki/Worldcon',
#  'https://en.wikipedia.org/wiki/Australian_science_fiction',
#  'https://en.wikipedia.org/wiki/Bengali_science_fiction',
#  'https://en.wikipedia.org/wiki/Brazilian_science_fiction',
#  'https://en.wikipedia.org/wiki/Canadian_science_fiction',
#  'https://en.wikipedia.org/wiki/Chilean_science_fiction',
#  'https://en.wikipedia.org/wiki/Chinese_science_fiction',
#  'https://en.wikipedia.org/wiki/Croatian_science_fiction',
#  'https://en.wikipedia.org/wiki/Czech_science_fiction_and_fantasy',
#  'https://en.wikipedia.org/wiki/Estonian_science_fiction',
#  'https://en.wikipedia.org/wiki/French_science_fiction',
#  'https://en.wikipedia.org/wiki/Hungarian_science_fiction',
#  'https://en.wikipedia.org/wiki/Japanese_science_fiction',
#  'https://en.wikipedia.org/wiki/Norwegian_science_fiction',
#  'https://en.wikipedia.org/wiki/Science_fiction_and_fantasy_in_Poland',
#  'https://en.wikipedia.org/wiki/Romanian_science_fiction',
#  'https://en.wikipedia.org/wiki/Russian_science_fiction_and_fantasy',
#  'https://en.wikipedia.org/wiki/Serbian_science_fiction',
#  'https://en.wikipedia.org/wiki/Spanish_science_fiction',
#  'https://en.wikipedia.org/wiki/Aurora_Awards',
#  'https://en.wikipedia.org/wiki/Chandler_Award',
#  'https://en.wikipedia.org/wiki/Dragon_Awards',
#  'https://en.wikipedia.org/wiki/Hugo_Award',
#  'https://en.wikipedia.org/wiki/Seiun_Award',
#  'https://en.wikipedia.org/wiki/Gaylactic_Spectrum_Awards',
#  'https://en.wikipedia.org/wiki/Jules_Verne_Award',
#  'https://en.wikipedia.org/wiki/Saturn_Award',
#  'https://en.wikipedia.org/wiki/Aurealis_Award',
#  'https://en.wikipedia.org/wiki/BSFA_Award',
#  'https://en.wikipedia.org/wiki/John_W._Campbell_Award_for_Best_New_Writer',
#  'https://en.wikipedia.org/wiki/John_W._Campbell_Memorial_Award_for_Best_Science_Fiction_Novel',
#  'https://en.wikipedia.org/wiki/Arthur_C._Clarke_Award',
#  'https://en.wikipedia.org/wiki/Compton_Crook_Award',
#  'https://en.wikipedia.org/wiki/Deutscher_Science_Fiction_Preis',
#  'https://en.wikipedia.org/wiki/Philip_K._Dick_Award',
#  'https://en.wikipedia.org/wiki/Ditmar_Award',
#  'https://en.wikipedia.org/wiki/Endeavour_Award',
#  'https://en.wikipedia.org/wiki/FantLab%27s_Book_of_the_Year_Award',
#  'https://en.wikipedia.org/wiki/Galaxy_Award_(China)',
#  'https://en.wikipedia.org/wiki/Jack_Gaughan_Award',
#  'https://en.wikipedia.org/wiki/Geffen_Award',
#  'https://en.wikipedia.org/wiki/Golden_Duck_Award',
#  'https://en.wikipedia.org/wiki/Damon_Knight_Memorial_Grand_Master_Award',
#  'https://en.wikipedia.org/wiki/Grand_prix_de_l%27Imaginaire',
#  'https://en.wikipedia.org/wiki/Paul_Harland_Prize',
#  'https://en.wikipedia.org/wiki/Robert_A._Heinlein_Award',
#  'https://en.wikipedia.org/wiki/Premio_Ignotus',
#  'https://en.wikipedia.org/wiki/Writers_of_the_Future',
#  'https://en.wikipedia.org/wiki/Kitschies',
#  'https://en.wikipedia.org/wiki/Lambda_Literary_Award',
#  'https://en.wikipedia.org/wiki/Kurd_La%C3%9Fwitz_Award',
#  'https://en.wikipedia.org/wiki/Locus_Award',
#  'https://en.wikipedia.org/wiki/Nautilus_Award',
#  'https://en.wikipedia.org/wiki/Nebula_Award',
#  'https://en.wikipedia.org/wiki/Andre_Norton_Award',
#  'https://en.wikipedia.org/wiki/Parsec_Awards',
#  'https://en.wikipedia.org/wiki/Prometheus_Award',
#  'https://en.wikipedia.org/wiki/Rhysling_Award',
#  'https://en.wikipedia.org/wiki/SFERA_Award',
#  'https://en.wikipedia.org/wiki/Sidewise_Award_for_Alternate_History',
#  'https://en.wikipedia.org/wiki/Edward_E._Smith_Memorial_Award',
#  'https://en.wikipedia.org/wiki/Theodore_Sturgeon_Award',
#  'https://en.wikipedia.org/wiki/Sunburst_Award',
#  'https://en.wikipedia.org/wiki/T%C3%A4htivaeltaja_Award',
#  'https://en.wikipedia.org/wiki/TBD_Science_Fiction_Story_Award',
#  'https://en.wikipedia.org/wiki/James_Tiptree_Jr._Award',
#  'https://en.wikipedia.org/wiki/Prix_Apollo_Award',
#  'https://en.wikipedia.org/wiki/Science_Fiction_%26_Fantasy_Translation_Awards',
#  'https://en.wikipedia.org/wiki/Urania_Award',
#  'https://en.wikipedia.org/wiki/Sir_Julius_Vogel_Award',
#  'https://en.wikipedia.org/wiki/Writers_of_the_Future',
#  'https://en.wikipedia.org/wiki/Janusz_A._Zajdel_Award',
#  'https://en.wikipedia.org/wiki/Science_fiction_comics',
#  'https://en.wikipedia.org/wiki/Science_fiction_magazine',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_novels',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_publishers',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_short_stories',
#  'https://en.wikipedia.org/wiki/Science_fiction_opera',
#  'https://en.wikipedia.org/wiki/Science_fiction_theatre',
#  'https://en.wikipedia.org/wiki/History_of_science_fiction_films',
#  'https://en.wikipedia.org/wiki/Science_fiction_films_in_India',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_television_programs',
#  'https://en.wikipedia.org/wiki/Australian_science_fiction_television',
#  'https://en.wikipedia.org/wiki/British_television_science_fiction',
#  'https://en.wikipedia.org/wiki/Canadian_science_fiction_television',
#  'https://en.wikipedia.org/wiki/Science_fiction_on_television#Continental_European_science_fiction_series',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_anime',
#  'https://en.wikipedia.org/wiki/Tokusatsu',
#  'https://en.wikipedia.org/wiki/U.S._television_science_fiction',
#  'https://en.wikipedia.org/wiki/Astronomical_engineering',
#  'https://en.wikipedia.org/wiki/AI_takeovers_in_popular_culture',
#  'https://en.wikipedia.org/wiki/Artificial_intelligence_in_fiction',
#  'https://en.wikipedia.org/wiki/Megastructure',
#  'https://en.wikipedia.org/wiki/Space_stations_and_habitats_in_fiction',
#  'https://en.wikipedia.org/wiki/Space_stations_and_habitats_in_fiction',
#  'https://en.wikipedia.org/wiki/Mind_uploading_in_fiction',
#  'https://en.wikipedia.org/wiki/Nanotechnology_in_fiction',
#  'https://en.wikipedia.org/wiki/Organ_transplantation_in_fiction',
#  'https://en.wikipedia.org/wiki/Prosthetics_in_fiction',
#  'https://en.wikipedia.org/wiki/List_of_fictional_robots_and_androids',
#  'https://en.wikipedia.org/wiki/Self-replicating_machine',
#  'https://en.wikipedia.org/wiki/Simulated_consciousness_in_fiction',
#  'https://en.wikipedia.org/wiki/Simulated_reality_in_fiction',
#  'https://en.wikipedia.org/wiki/Space_warfare_in_fiction',
#  'https://en.wikipedia.org/wiki/Terraforming_in_popular_culture',
#  'https://en.wikipedia.org/wiki/Technomancy',
#  'https://en.wikipedia.org/wiki/Fermi_paradox',
#  'https://en.wikipedia.org/wiki/Grandfather_paradox',
#  'https://en.wikipedia.org/wiki/Time_travel_in_fiction',
#  'https://en.wikipedia.org/wiki/Biological_warfare_in_popular_culture',
#  'https://en.wikipedia.org/wiki/Evolution_in_fiction',
#  'https://en.wikipedia.org/wiki/Extraterrestrials_in_fiction',
#  'https://en.wikipedia.org/wiki/List_of_fictional_extraterrestrials',
#  'https://en.wikipedia.org/wiki/List_of_fictional_extraterrestrials',
#  'https://en.wikipedia.org/wiki/Genetic_engineering_in_science_fiction',
#  'https://en.wikipedia.org/wiki/Gender_in_speculative_fiction',
#  'https://en.wikipedia.org/wiki/Group_mind_(science_fiction)',
#  'https://en.wikipedia.org/wiki/Parasites_in_fiction',
#  'https://en.wikipedia.org/wiki/Sex_and_sexuality_in_speculative_fiction',
#  'https://en.wikipedia.org/wiki/Symbiosis_in_fiction',
#  'https://en.wikipedia.org/wiki/Faster-than-light',
#  'https://en.wikipedia.org/wiki/Heim_theory',
#  'https://en.wikipedia.org/wiki/Hyperdrive',
#  'https://en.wikipedia.org/wiki/Hyperspace',
#  'https://en.wikipedia.org/wiki/Jump_drive',
#  'https://en.wikipedia.org/wiki/Warp_drive',
#  'https://en.wikipedia.org/wiki/Wormholes_in_fiction',
#  'https://en.wikipedia.org/wiki/Heim_theory',
#  'https://en.wikipedia.org/wiki/Hyperdrive',
#  'https://en.wikipedia.org/wiki/Hyperspace',
#  'https://en.wikipedia.org/wiki/Jump_drive',
#  'https://en.wikipedia.org/wiki/Warp_drive',
#  'https://en.wikipedia.org/wiki/Wormholes_in_fiction',
#  'https://en.wikipedia.org/wiki/Earth_in_science_fiction',
#  'https://en.wikipedia.org/wiki/Multiverse',
#  'https://en.wikipedia.org/wiki/Parallel_universes_in_fiction',
#  'https://en.wikipedia.org/wiki/Planets_in_science_fiction',
#  'https://en.wikipedia.org/wiki/Stars_and_planetary_systems_in_fiction',
#  'https://en.wikipedia.org/wiki/Ancient_astronauts_in_popular_culture',
#  'https://en.wikipedia.org/wiki/Alien_invasion',
#  'https://en.wikipedia.org/wiki/Alien_language',
#  'https://en.wikipedia.org/wiki/Black_science_fiction',
#  'https://en.wikipedia.org/wiki/Cyborgs_in_fiction',
#  'https://en.wikipedia.org/wiki/Evil_corporation',
#  'https://en.wikipedia.org/wiki/Feminist_science_fiction',
#  'https://en.wikipedia.org/wiki/First_contact_(science_fiction)',
#  'https://en.wikipedia.org/wiki/Frankenstein_complex',
#  'https://en.wikipedia.org/wiki/Galactic_empire',
#  'https://en.wikipedia.org/wiki/LGBT_themes_in_speculative_fiction',
#  'https://en.wikipedia.org/wiki/Libertarian_science_fiction',
#  'https://en.wikipedia.org/wiki/Message_from_space_(science_fiction)',
#  'https://en.wikipedia.org/wiki/Political_ideas_in_science_fiction',
#  'https://en.wikipedia.org/wiki/List_of_religious_ideas_in_science_fiction',
#  'https://en.wikipedia.org/wiki/List_of_science_fiction_horror_films',
#  'https://en.wikipedia.org/wiki/Transhumanism_in_fiction',
#  'https://en.wikipedia.org/wiki/Uplift_(science_fiction)',
#  'https://en.wikipedia.org/wiki/World_government_in_fiction',
#  'https://en.wikipedia.org/wiki/Xenoarchaeology',
#  'https://en.wikipedia.org/wiki/Alternate_history',
#  'https://en.wikipedia.org/wiki/Afrofuturism',
#  'https://en.wikipedia.org/wiki/Fantasy',
#  'https://en.wikipedia.org/wiki/Fictional_technology',
#  'https://en.wikipedia.org/wiki/Future',
#  'https://en.wikipedia.org/wiki/Future_history',
#  'https://en.wikipedia.org/wiki/Horror_fiction',
#  'https://en.wikipedia.org/wiki/Magic_realism',
#  'https://en.wikipedia.org/wiki/Mecha',
#  'https://en.wikipedia.org/wiki/Rubber_science',
#  'https://en.wikipedia.org/wiki/Science_and_technology_studies',
#  'https://en.wikipedia.org/wiki/Science_fantasy',
#  'https://en.wikipedia.org/wiki/Speculative_fiction',
#  'https://en.wikipedia.org/wiki/Spy-Fi_(subgenre)',
#  'https://en.wikipedia.org/wiki/Superhero_fiction',
#  'https://en.wikipedia.org/wiki/Supernatural_fiction',
#  'https://en.wikipedia.org/wiki/Weird_fiction',
#  'https://en.wikipedia.org/wiki/Techno-thriller',
#  'https://en.wikipedia.org/wiki/Technology_and_society',
#  'https://en.wikipedia.org/wiki/Utopian_and_dystopian_fiction',
#  'https://en.wikipedia.org/wiki/Category:Science_fiction',
#  'https://en.wikipedia.org/wiki/Portal:Speculative_fiction/Science_fiction',
#  'https://en.wikipedia.org/wiki/Category:Lists_of_science_fiction_films',
#  'https://en.wikipedia.org/wiki/Category:Science_fiction_films',
#  'https://en.wikipedia.org/wiki/Category:Lists_of_works_of_science_fiction,_arranged_in_chronological_order',
#  'https://en.wikipedia.org/wiki/Special:MyTalk',
#  'https://en.wikipedia.org/wiki/Special:MyContributions',
#  'https://en.wikipedia.org/w/index.php?title=Special:CreateAccount&returnto=Lists+of+science+fiction+films',
#  'https://en.wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Lists+of+science+fiction+films',
#  'https://en.wikipedia.org/wiki/Lists_of_science_fiction_films',
#  'https://en.wikipedia.org/wiki/Talk:Lists_of_science_fiction_films',
#  'https://en.wikipedia.org/wiki/Lists_of_science_fiction_films',
#  'https://en.wikipedia.org/w/index.php?title=Lists_of_science_fiction_films&action=edit',
#  'https://en.wikipedia.org/w/index.php?title=Lists_of_science_fiction_films&action=history',
#  'https://en.wikipedia.org/wiki/Main_Page',
#  'https://en.wikipedia.org/wiki/Portal:Contents',
#  'https://en.wikipedia.org/wiki/Portal:Featured_content',
#  'https://en.wikipedia.org/wiki/Portal:Current_events',
#  'https://en.wikipedia.org/wiki/Special:Random',
#  'https://en.wikipedia.orghttps://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en',
#  'https://en.wikipedia.org//shop.wikimedia.org',
#  'https://en.wikipedia.org/wiki/Help:Contents',
#  'https://en.wikipedia.org/wiki/Wikipedia:About',
#  'https://en.wikipedia.org/wiki/Wikipedia:Community_portal',
#  'https://en.wikipedia.org/wiki/Special:RecentChanges',
#  'https://en.wikipedia.org//en.wikipedia.org/wiki/Wikipedia:Contact_us',
#  'https://en.wikipedia.org/wiki/Special:WhatLinksHere/Lists_of_science_fiction_films',
#  'https://en.wikipedia.org/wiki/Special:RecentChangesLinked/Lists_of_science_fiction_films',
#  'https://en.wikipedia.org/wiki/Wikipedia:File_Upload_Wizard',
#  'https://en.wikipedia.org/wiki/Special:SpecialPages',
#  'https://en.wikipedia.org/w/index.php?title=Lists_of_science_fiction_films&oldid=910068559',
#  'https://en.wikipedia.org/w/index.php?title=Lists_of_science_fiction_films&action=info',
#  'https://en.wikipedia.orghttps://www.wikidata.org/wiki/Special:EntityPage/Q2441984',
#  'https://en.wikipedia.org/w/index.php?title=Special:CiteThisPage&page=Lists_of_science_fiction_films&id=910068559',
#  'https://en.wikipedia.org/w/index.php?title=Special:Book&bookcmd=book_creator&referer=Lists+of+science+fiction+films',
#  'https://en.wikipedia.org/w/index.php?title=Special:ElectronPdf&page=Lists+of+science+fiction+films&action=show-download-screen',
#  'https://en.wikipedia.org/w/index.php?title=Lists_of_science_fiction_films&printable=yes',
#  'https://en.wikipedia.orghttps://af.wikipedia.org/wiki/Lys_van_wetenskapsfiksierolprente',
#  'https://en.wikipedia.orghttps://de.wikipedia.org/wiki/Liste_von_Science-Fiction-Filmen',
#  'https://en.wikipedia.orghttps://es.wikipedia.org/wiki/Anexo:Pel%C3%ADculas_de_ciencia_ficci%C3%B3n',
#  'https://en.wikipedia.orghttps://fr.wikipedia.org/wiki/Chronologie_du_cin%C3%A9ma_de_science-fiction',
#  'https://en.wikipedia.orghttps://hr.wikipedia.org/wiki/Dodatak:Popis_ZF_filmova',
#  'https://en.wikipedia.orghttps://it.wikipedia.org/wiki/Progetto:Fantascienza/Elenco_di_film',
#  'https://en.wikipedia.orghttps://nl.wikipedia.org/wiki/Lijst_van_sciencefictionfilms',
#  'https://en.wikipedia.orghttps://ja.wikipedia.org/wiki/SF%E6%98%A0%E7%94%BB%E3%81%AE%E4%B8%80%E8%A6%A7',
#  'https://en.wikipedia.orghttps://ro.wikipedia.org/wiki/List%C4%83_de_filme_%C8%99tiin%C8%9Bifico-fantastice',
#  'https://en.wikipedia.orghttps://ru.wikipedia.org/wiki/%D0%9F%D1%80%D0%BE%D0%B5%D0%BA%D1%82:%D0%9A%D0%B8%D0%BD%D0%BE/%D0%A1%D0%BF%D0%B8%D1%81%D0%BA%D0%B8/%D0%A1%D0%BF%D0%B8%D1%81%D0%BE%D0%BA_%D0%BD%D0%B0%D1%83%D1%87%D0%BD%D0%BE-%D1%84%D0%B0%D0%BD%D1%82%D0%B0%D1%81%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B8%D1%85_%D1%84%D0%B8%D0%BB%D1%8C%D0%BC%D0%BE%D0%B2',
#  'https://en.wikipedia.orghttps://sl.wikipedia.org/wiki/Seznam_znanstvenofantasti%C4%8Dnih_filmov',
#  'https://en.wikipedia.orghttps://fi.wikipedia.org/wiki/Luettelo_tieteiselokuvista',
#  'https://en.wikipedia.orghttps://tr.wikipedia.org/wiki/Bilimkurgu_filmleri_listesi',
#  'https://en.wikipedia.org//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#  'https://en.wikipedia.org//creativecommons.org/licenses/by-sa/3.0/',
#  'https://en.wikipedia.org//foundation.wikimedia.org/wiki/Terms_of_Use',
#  'https://en.wikipedia.org//foundation.wikimedia.org/wiki/Privacy_policy',
#  'https://en.wikipedia.org//www.wikimediafoundation.org/',
#  'https://en.wikipedia.orghttps://foundation.wikimedia.org/wiki/Privacy_policy',
#  'https://en.wikipedia.org/wiki/Wikipedia:About',
#  'https://en.wikipedia.org/wiki/Wikipedia:General_disclaimer',
#  'https://en.wikipedia.org//en.wikipedia.org/wiki/Wikipedia:Contact_us',
#  'https://en.wikipedia.orghttps://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute',
#  'https://en.wikipedia.orghttps://foundation.wikimedia.org/wiki/Cookie_statement',
#  'https://en.wikipedia.org//en.m.wikipedia.org/w/index.php?title=Lists_of_science_fiction_films&mobileaction=toggle_view_mobile',
#  'https://en.wikipedia.orghttps://wikimediafoundation.org/',
#  'https://en.wikipedia.orghttps://www.mediawiki.org/']

# %%
# create two new lists, one for the title of the page, 
# and one for the link to the page
film_titles = []
film_links = []
# for loop to pull from each decade page with list of films.
# look at https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_1920s
# to follow along as an exampe
for decade in decade_links[-2:]:
    print(f'Collecting films from {decade}')
    html = requests.get(decade)
    b = BeautifulSoup(html.text, 'lxml')
    # get to the table on the page
    for i in b.find_all(name='table', class_='wikitable'):
        # get to the row of each film
        for j in i.find_all(name='tr'):
            #get just the title cell for each row.
            # contains the title and the URL
            for k in j.find_all(name='i'):
                # get within that cell to just get the words
                for link in k.find_all('a', href=True):
                    # get the title and add to the list
                    film_titles.append(link['title'])
                    # get the link and add to that list
                    film_links.append(link['href'])
    #be a conscientious scraper and pause between scrapes
    time.sleep(1)
print(f'Number of Film Links Collected: {len(film_links)}')
print(f'Number of Film Titles Collected: {len(film_titles)}')
# remove film links that don't have a description page on Wikipedia
new_film_links = [i for i in film_links if 'redlink' not in i]
# same goes for titles
new_film_titles = [i for i in film_titles if '(page does not exist)' not in i]
print(f'Number of Film Links with Wikipedia Pages: {len(new_film_links)}')
print(f'Number of Film Titles with Wikipedia Pages: {len(new_film_titles)}')
#use this list to fetch from the API
title_links = list(zip(new_film_titles, new_film_links))
# Out:
# Collecting films from https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_2010s
# Collecting films from https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_2020s
# Number of Film Links Collected: 361
# Number of Film Titles Collected: 361
# Number of Film Links with Wikipedia Pages: 358
# Number of Film Titles with Wikipedia Pages: 358

# %%
title_links

# %%
titulo = []
director = []
actores = []
pais = []
fecha = []

# %%
for decade in decade_links[-2:]:
    print(f'Collecting films from {decade}')
    html = requests.get(decade)
    b = BeautifulSoup(html.text, 'lxml')
    # get to the table on the page
    for i in b.find_all(name='table', class_='wikitable'):
        for row in i.find_all('tr'):
#             print(row)
            cells=row.find_all('td')
            if len(cells)==5:
                titulo.append(cells[0].find(text=True))
                director.append(cells[1].find(text=True))
                actores.append(cells[2].find(text=True))
                pais.append(cells[3].find("a",href=True)['title'])
                fecha.append(cells[4].find(text=True).rstrip('\n'))
#                 break
# Out:
# Collecting films from https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_2010s
# Collecting films from https://en.wikipedia.org/wiki/List_of_science_fiction_films_of_the_2020s

# %%
len(titulo)
# Out:
# 373

# %%
# cells[0].find(text=True)
# cells[1].find(text=True)
# cells[2].find(text=True)
# cells[3].find("a",href=True)['title']
# cells[4].find(text=True).rstrip('\n')
# Out:
# '2020'

# %%
df=pd.DataFrame(titulo,columns=['Titulo'])
df['Director']=director
df['Actores']=actores
df['Pais']=pais
df['Fecha']=fecha

# %%
df
# Out:
#                                    Titulo               Director  \
# 0                              After Yang               Kogonada
# 1               Bill & Ted Face the Music           Dean Parisot
# 2                                    BIOS       Miguel Sapochnik
# 3                           Chaos Walking             Doug Liman
# 4                                    Dune       Denis Villeneuve
# 5                     Evangelion: 3.0+1.0           Hideaki Anno
# 6                       Godzilla vs. Kong           Adam Wingard
# 7                         The New Mutants             Josh Boone
# 8                                Stowaway              Joe Penna
# 9                                Voyagers            Neil Burger
# 10                               Avatar 2          James Cameron
# 11                               Avatar 3          James Cameron
# 12                               Altitude          Kaare Andrews
# 13                         Alien vs Ninja            Seiji Chiba
# 14                           Arctic Blast  Brian Trenchard-Smith
# 15             Batman: Under the Red Hood         Brandon Vietti
# 16               Beyond the Black Rainbow         Panos Cosmatos
# 17                        The Book of Eli          Albert Hughes
# 18                            The Crazies           Breck Eisner
# 19                            Daybreakers          Peter Spierig
# 20                                Denizen             J.A. Steel
# 21                          Despicable Me          Pierre Coffin
# 22   The Disappearance of Haruhi Suzumiya       Tatsuya Ishihara
# 23                             Downstream      Simone Bartesaghi
# 24                               Enthiran             S. Shankar
# 25                          Future X-Cops              Wong Jing
# 26                                 Growth          Gabriel Cowan
# 27                   Hot Tub Time Machine            Sean Anders
# 28                            Hunter Prey          Sandy Collora
# 29                              Inception      Christopher Nolan
# ..                                    ...                    ...
# 343                         Captive State           Rupert Wyatt
# 344                           Crazy Alien               Ning Hao
# 345                          Dark Phoenix          Simon Kinberg
# 346        Godzilla: King of the Monsters      Michael Dougherty
# 347                           I Am Mother          Grant Sputore
# 348                                    Io       Jonathan Helpert
# 349             Iron Sky: The Coming Race        Timo Vuorensola
# 350           Men in Black: International           F. Gary Gray
# 351                         Project Ghazi             Nadir Shah
# 352                              Replicas     Jeffrey Nachmanoff
# 353                         Short Circuit          Faisal Hashmi
# 354                   The Wandering Earth              Frant Gwo
# 355                              Ad Astra             James Gray
# 356                            Gemini Man                Ang Lee
# 357      Star Wars: The Rise of Skywalker           J. J. Abrams
# 358                 Terminator: Dark Fate             Tim Miller
# 359                The Three-Body Problem           Panpan Zhang
# 360                    Warriors of Future            Ng Yuen-fai
# 361                            After Yang               Kogonada
# 362             Bill & Ted Face the Music           Dean Parisot
# 363                                  BIOS       Miguel Sapochnik
# 364                         Chaos Walking             Doug Liman
# 365                                  Dune       Denis Villeneuve
# 366                   Evangelion: 3.0+1.0           Hideaki Anno
# 367                     Godzilla vs. Kong           Adam Wingard
# 368                       The New Mutants             Josh Boone
# 369                              Stowaway              Joe Penna
# 370                              Voyagers            Neil Burger
# 371                              Avatar 2          James Cameron
# 372                              Avatar 3          James Cameron
#
#                    Actores            Pais                            Fecha
# 0            Colin Farrell   United States                             2020
# 1             Keanu Reeves   United States                  August 21, 2020
# 2                Tom Hanks   United States                  October 2, 2020
# 3              Tom Holland   United States                             2020
# 4        Timothée Chalamet   United States                November 20, 2020
# 5                     None           Japan                       June, 2020
# 6            Kyle Chandler   United States                   March 13, 2020
# 7          Anya Taylor-Joy   United States                    April 3, 2020
# 8            Anna Kendrick   United States                             2020
# 9            Colin Farrell   United States                             2020
# 10         Sam Worthington   United States                December 17, 2021
# 11         Sam Worthington   United States                December 22, 2023
# 12         Jessica Lowndes          Canada                           Horror
# 13      Shuuji Kashiwabara           Japan                           Action
# 14          Michael Shanks       Australia                         Disaster
# 15         Bruce Greenwood   United States          Animated superhero film
# 16          Michael Rogers          Canada                          Mystery
# 17       Denzel Washington   United States                 Post-apocalyptic
# 18        Timothy Olyphant   United States                           Horror
# 19             Ethan Hawke   United States                          Vampire
# 20              J.A. Steel   United States                    Action horror
# 21            Steve Carell   United States  Family-oriented animated comedy
# 22              Aya Hirano           Japan                            Anime
# 23          Jonathon Trent   United States          Post-apocalyptic action
# 24             Rajinikanth           India                   Robot Uprising
# 25                Andy Lau           China                      Time travel
# 26           Mircea Monroe   United States                           Horror
# 27             Rob Corddry   United States                           Comedy
# 28           Clark Bartram   United States                         Thriller
# 29       Leonardo DiCaprio  United Kingdom                  Action thriller
# ..                     ...             ...                              ...
# 343           John Goodman   United States
# 344               Huang Bo           China
# 345           James McAvoy   United States
# 346     Millie Bobby Brown   United States
# 347          Clara Rugaard       Australia
# 348       Margaret Qualley   United States
# 349           Julia Dietze         Finland
# 350        Chris Hemsworth   United States
# 351          Humayun Saeed        Pakistan
# 352           Keanu Reeves   United States
# 353         Dhvanit Thaker           India                     Comedy drama
# 354                Wu Jing           China
# 355              Brad Pitt   United States               September 20, 2019
# 356             Will Smith   United States                  October 4, 2019
# 357            Adam Driver   United States                December 20, 2019
# 358  Arnold Schwarzenegger   United States                 November 1, 2019
# 359          Zhang Jingchu           China                             [46]
# 360              Louis Koo       Hong Kong
# 361          Colin Farrell   United States                             2020
# 362           Keanu Reeves   United States                  August 21, 2020
# 363              Tom Hanks   United States                  October 2, 2020
# 364            Tom Holland   United States                             2020
# 365      Timothée Chalamet   United States                November 20, 2020
# 366                   None           Japan                       June, 2020
# 367          Kyle Chandler   United States                   March 13, 2020
# 368        Anya Taylor-Joy   United States                    April 3, 2020
# 369          Anna Kendrick   United States                             2020
# 370          Colin Farrell   United States                             2020
# 371        Sam Worthington   United States                December 17, 2021
# 372        Sam Worthington   United States                December 22, 2023
#
# [373 rows x 5 columns]
